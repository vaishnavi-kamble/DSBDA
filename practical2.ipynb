# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("pima-indians-diabetes.csv",names=['Number of times pregnant','Plasma glucose concentration a 2 hours in oral glucose tolerance test','Diastolic blood pressure (mm Hg)',''','2-Hour serum insulin (mu U/ml) ','Body mass index (weight in kg/(height in m)^2)','Diabetes pedigree function','Age (years)','Class variable (0 or 1)'])
data
# Out:
#                               Number of times pregnant  \
# 0                        # 1. Number of times pregnant
# 1    # 2. Plasma glucose concentration a 2 hours in...
# 2                # 3. Diastolic blood pressure (mm Hg)
# 3                # 4. Triceps skin fold thickness (mm)
# 4                  # 5. 2-Hour serum insulin (mu U/ml)
# ..                                                 ...
# 772                                                 10
# 773                                                  2
# 774                                                  5
# 775                                                  1
# 776                                                  1
#
#      Plasma glucose concentration a 2 hours in oral glucose tolerance test  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# ...

# %% [markdown]
# a.Data Cleaning

# %%
data.isna().sum()
# Out:
# Number of times pregnant                                                  0
# Plasma glucose concentration a 2 hours in oral glucose tolerance test    12
# Diastolic blood pressure (mm Hg)                                         10
# Triceps skin fold thickness (mm)                                         10
# 2-Hour serum insulin (mu U/ml)                                           10
# Body mass index (weight in kg/(height in m)^2)                           11
# Diabetes pedigree function                                               10
# Age (years)                                                               9
# Class variable (0 or 1)                                                   9
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 777 entries, 0 to 776
# Data columns (total 9 columns):
#  #   Column                                                                 Non-Null Count  Dtype
# ---  ------                                                                 --------------  -----
#  0   Number of times pregnant                                               777 non-null    object
#  1   Plasma glucose concentration a 2 hours in oral glucose tolerance test  765 non-null    float64
#  2   Diastolic blood pressure (mm Hg)                                       767 non-null    float64
#  3   Triceps skin fold thickness (mm)                                       767 non-null    float64
#  4   2-Hour serum insulin (mu U/ml)                                         767 non-null    float64
#  5   Body mass index (weight in kg/(height in m)^2)                         766 non-null    float64
# ...

# %%
data.shape
data
# Out:
#                               Number of times pregnant  \
# 0                        # 1. Number of times pregnant
# 1    # 2. Plasma glucose concentration a 2 hours in...
# 2                # 3. Diastolic blood pressure (mm Hg)
# 3                # 4. Triceps skin fold thickness (mm)
# 4                  # 5. 2-Hour serum insulin (mu U/ml)
# ..                                                 ...
# 772                                                 10
# 773                                                  2
# 774                                                  5
# 775                                                  1
# 776                                                  1
#
#      Plasma glucose concentration a 2 hours in oral glucose tolerance test  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# ...

# %%
data.describe()
# Out:
#        Plasma glucose concentration a 2 hours in oral glucose tolerance test  \
# count                                         765.000000
# mean                                          120.773856
# std                                            31.893226
# min                                             0.000000
# 25%                                            99.000000
# 50%                                           117.000000
# 75%                                           140.000000
# max                                           199.000000
#
#        Diastolic blood pressure (mm Hg)  Triceps skin fold thickness (mm)  \
# count                        767.000000                        767.000000
# mean                          69.114733                         20.518905
# std                           19.366734                         15.955203
# min                            0.000000                          0.000000
# ...

# %%
#removing first 9 rows and resseting the index
data = data.iloc[9:,:] 
data =data.reset_index(drop=True)
data
# Out:
#     Number of times pregnant  \
# 0                          6
# 1                          1
# 2                          8
# 3                          1
# 4                          0
# ..                       ...
# 763                       10
# 764                        2
# 765                        5
# 766                        1
# 767                        1
#
#      Plasma glucose concentration a 2 hours in oral glucose tolerance test  \
# 0                                                148.0
# 1                                                 85.0
# 2                                                183.0
# 3                                                 89.0
# 4                                                137.0
# ..                                                 ...
# 763                                              101.0
# 764                                              122.0
# 765                                              121.0
# ...

# %%
#Fills missing values with the mean of each column.
data = data.fillna(value = data.mean(numeric_only = True))
data
# Out:
#     Number of times pregnant  \
# 0                          6
# 1                          1
# 2                          8
# 3                          1
# 4                          0
# ..                       ...
# 763                       10
# 764                        2
# 765                        5
# 766                        1
# 767                        1
#
#      Plasma glucose concentration a 2 hours in oral glucose tolerance test  \
# 0                                                148.0
# 1                                                 85.0
# 2                                                183.0
# 3                                                 89.0
# 4                                                137.0
# ..                                                 ...
# 763                                              101.0
# 764                                              122.0
# 765                                              121.0
# ...

# %%
data.isnull().sum()
# Out:
# Number of times pregnant                                                 0
# Plasma glucose concentration a 2 hours in oral glucose tolerance test    0
# Diastolic blood pressure (mm Hg)                                         0
# Triceps skin fold thickness (mm)                                         0
# 2-Hour serum insulin (mu U/ml)                                           0
# Body mass index (weight in kg/(height in m)^2)                           0
# Diabetes pedigree function                                               0
# Age (years)                                                              0
# Class variable (0 or 1)                                                  0
# dtype: int64

# %% [markdown]
# b.Data Integration

# %%
subs1 = data[data['Age (years)']>50]
#subs1.shape

# %%
subs2 = data[data['Diastolic blood pressure (mm Hg)']>60]
#subs2.shape

# %%
merged = pd.concat([subs1,subs2])
merged
# Out:
#     Number of times pregnant  \
# 8                          2
# 9                          8
# 12                        10
# 13                         1
# 14                         5
# ..                       ...
# 762                        9
# 763                       10
# 764                        2
# 765                        5
# 767                        1
#
#      Plasma glucose concentration a 2 hours in oral glucose tolerance test  \
# 8                                                197.0
# 9                                                125.0
# 12                                               139.0
# 13                                               189.0
# 14                                               166.0
# ..                                                 ...
# 762                                               89.0
# 763                                              101.0
# 764                                              122.0
# ...

# %%
#correlation matrix , Visualizes correlations between variables.
corr_mat = sns.heatmap(data=data.corr(),annot=True)
corr_mat
# Out:
# <Axes: >

# %%
#Splitting Data for Model Training
from sklearn.model_selection import train_test_split
x=data.iloc[:,0:8]
y = data['Class variable (0 or 1)']
train_x,test_x,train_y,test_y = train_test_split(x,y,test_size=0.2,random_state=0)

# %%
train_x
# Out:
#     Number of times pregnant  \
# 603                        7
# 118                        4
# 247                        0
# 157                        1
# 468                        8
# ..                       ...
# 763                       10
# 192                        7
# 629                        4
# 559                       11
# 684                        5
#
#      Plasma glucose concentration a 2 hours in oral glucose tolerance test  \
# 603                                              150.0
# 118                                               97.0
# 247                                              165.0
# 157                                              109.0
# 468                                              120.0
# ..                                                 ...
# 763                                              101.0
# 192                                              159.0
# 629                                               94.0
# ...

# %%
train_y
# Out:
# 603    1.0
# 118    0.0
# 247    0.0
# 157    0.0
# 468    1.0
#       ...
# 763    0.0
# 192    1.0
# 629    0.0
# 559    0.0
# 684    0.0
# Name: Class variable (0 or 1), Length: 614, dtype: float64

# %%
#Creates and trains a Decision Tree Classifier.
from sklearn import tree
model = tree.DecisionTreeClassifier()
model.fit(train_x,train_y)
# Out:
# DecisionTreeClassifier()

# %%
#Predicts diabetes (0 or 1) for test data.
ypred = model.predict(test_x)

# %%
#Evaluating Model Performance
from sklearn.metrics import confusion_matrix,accuracy_score,recall_score,precision_score,f1_score
matrix = confusion_matrix(test_y,ypred)
matrix
# Out:
# array([[85, 22],
#        [15, 32]])

# %%
accuracy_score(test_y,ypred)
# Out:
# 0.7597402597402597

# %%
recall_score(test_y,ypred)
# Out:
# np.float64(0.6808510638297872)

# %%
precision_score(test_y,ypred)
# Out:
# np.float64(0.5925925925925926)

# %%
f1_score(test_y,ypred)
# Out:
# np.float64(0.6336633663366337)

# %%
#Displays the importance of each feature in decision making.
model.feature_importances_
# Out:
# array([0.05982606, 0.31477249, 0.10828204, 0.02485007, 0.03076033,
#        0.21936289, 0.11296565, 0.12918046])

# %%
from sklearn.tree import plot_tree
plt.figure(figsize=(20,16))
plot_tree(model, filled=True, feature_names=x.columns, class_names=['No Diabetes', 'Diabetes'])
plt.show()

# %% [markdown]
#  Number of times pregnant                                               768 non-null    object
#  1   Plasma glucose concentration a 2 hours in oral glucose tolerance test  765 non-null    float64
#  2   Diastolic blood pressure (mm Hg)                                       767 non-null    float64
#  3   Triceps skin fold thickness (mm)                                       767 non-null    float64
#  4   2-Hour serum insulin (mu U/ml)                                         767 non-null    float64
#  5   Body mass index (weight in kg/(height in m)^2)                         766 non-null    float64
#  6   Diabetes pedigree function                                             767 non-null    float64
#  7   Age (years)

# %%
#Predicts whether a patient with given values has diabetes.

pred = model.predict([[6,148.0,72.0,35.0,0.0,33.6,0.627,50.0]])

def prediction(pred):
   if pred == 1:
      return 'Diabetic'
   else:
      return 'NON Diabetic'

f"patient:{prediction(pred)}"
# Out:
# C:\Users\vaish\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# 'patient:Diabetic'

# %%
#Takes user input and predicts diabetes.

preg=input("enter Number of times pregnant ")
glu_level=input("Plasma glucose concentration a 2 hours in oral glucose tolerance test")
bld_pres=input("Diastolic blood pressure (mm Hg)")
skin_thick=input("Triceps skin fold thickness (mm)")
insulin=input("2-Hour serum insulin (mu U/ml)")
bmi=input("Body mass index (weight in kg/(height in m)^2)")
dbf=input("Diabetes pedigree function")
age = input("Age (years)")

pred = model.predict([[preg,glu_level,bld_pres,skin_thick,insulin,bmi,dbf,age ]])
f"patient:{prediction(pred)}"
# Out:
# enter Number of times pregnant  1
# Plasma glucose concentration a 2 hours in oral glucose tolerance test 90
# Diastolic blood pressure (mm Hg) 75
# Triceps skin fold thickness (mm) 25
# 2-Hour serum insulin (mu U/ml) 80
# Body mass index (weight in kg/(height in m)^2) 22.5
# Diabetes pedigree function 0.3
# Age (years) 25
# C:\Users\vaish\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# 'patient:NON Diabetic'
